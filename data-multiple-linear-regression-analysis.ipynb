# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: black; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> 📊 Data 📈 Multiple Linear Regression Analysis 🧩</p>

# %% [markdown]
# ![image.png](attachment:927f6c65-9f73-4ed9-bd8e-2c1e22d07629.png)

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: pink; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: black; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> 🥇 About Author</p>

# %% [markdown]
# * Madiha (her/she)
# * A certified secondary education teacher in history and geography, I work in a high school.
# * In parallel, I'm currently studing Accounting & Finance.
# * Interested in Data Analysis.

# %% [markdown]
# ## <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: khaki; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: black; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> 📍 About Dataset</p>

# %% [markdown]
# * This data are real and collected by Me. Contains my students markes in History and Geography subject.
# * In a public high school in Algeria, during this school year (2023/2024).
# * It includes general information about students: 'Identification_Number','Gender', 'Department', 'Level', 'Group','Result'.
# * It includes information about the grades obtained during the first, second, and third trimesters; in::'Continuous_Evaluation','Test', 'Exam','TRIO','Annual Rate'.

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: #ffcc99; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: black; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;">  🎯 About Objectives</p>

# %% [markdown]
# 1. To compare performance by gender, departments, levels and groups.
# 1. To compare the performance of students in the first, second and third trimesters.
# 1. To understand the impact of continuous evaluation marks on students' trimesters.
# 1. To understand the impact of continuous evaluation marks on the final results of students.

# %% [markdown]
# # <p style="width: 800px; border-radius: 12px; border: 3px dashed yellow; padding: 20px; background-color: blue; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: yellow; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> 🛣️ Roadmap </p>

# %% [markdown]
# - [1 | Follow Data](#1)
#    > - [Reading the Dataset](#1.1)
#    > - [View some statistical information](#1.2)
#
#
# - [2 | Make Charts](#2)
#    > - [Pie Chart](#2.1)
#    > - [Distributions](#2.2)
#    > - [Bar Charts](#2.3)
#    > - [Scatter plot](#2.4)
#
#
# - [3 | Extract Relations](#3)
#    > - [FIRST TRIO](#3.1)
#    > - [SECOND TRIO](#3.2)
#    > - [THIRD TRIO](#3.3)
#    > - [Extraction](#3.4)
#
#
# - [4 | Explore Pattern](#4)
#    > - [Annual Rate](#4.1)
#    > - [Conclusion](#4.2)

# %% [markdown]
# <a id='1'></a>
# # 1 | Follow Data

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: #66CDAA; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color:white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> 🔎 Follow Data</p>

# %% [markdown]
# #### Importing libraries
# |`numpy` | `pandas` | `matplotlib` |`seaborn` |`plotly` |`sklearn` |`scipy` |

# %%
# Importing libraries
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# We will use some methods from the sklearn module
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression
import scipy.stats as stats

from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split, cross_val_score
matplotlib.style.use('ggplot')

# import warnings
import warnings
warnings.filterwarnings("ignore")

# Configuring styles
sns.set_style("darkgrid")
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/studentsperformance-in-history-and-geography-subject/StudentsPerformance_His_Geo.csv

# %% [markdown]
# <a id='1.1'></a>
# ## Reading the Dataset

# %%
# Reading the Dataset
df = pd.read_csv("/kaggle/input/studentsperformance-in-history-and-geography-subject/StudentsPerformance_His_Geo.csv")
df
# Out:
#      Identification_Number Gender Date_of_Birth  \
# 0             1.100730e+15      F    2007-12-31
# 1             1.100717e+15      F    2007-08-30
# 2             1.100730e+15      F    2007-04-10
# 3             1.101230e+15      F    2007-09-13
# 4             1.100630e+15      F    2006-10-02
# ..                     ...    ...           ...
# 230           1.000730e+15      M    2007-06-13
# 231           1.000630e+15      M    2006-03-20
# 232           1.000630e+15      M    2006-05-18
# 233           1.000630e+15      M    2006-05-12
# 234           1.000539e+15      M    2005-05-24
#
#                                         Department             Level Group  \
# 0                            Experimental-Sciences  Second_secondary   2_1
# 1                            Experimental-Sciences  Second_secondary   2_1
# 2                            Experimental-Sciences  Second_secondary   2_1
# 3                            Experimental-Sciences  Second_secondary   2_1
# ...

# %% [markdown]
# #### List of columns

# %%
df.columns.tolist()
# Out:
# ['Identification_Number',
#  'Gender',
#  'Date_of_Birth',
#  'Department',
#  'Level',
#  'Group',
#  'Continuous_Evaluation_01',
#  'Test_01',
#  'Exam_01',
#  'FIRST_TRIO',
#  'Continuous_Evaluation_02',
#  'Test_02',
#  'Exam_02',
#  'SECOND_TRIO',
#  'Continuous_Evaluation_03',
#  'Test_03',
#  'Exam_03',
#  'THIRD_TRIO',
#  'Annual_ Rate',
#  'Result']

# %% [markdown]
# #### View some basic information about the data frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Identification_Number     235 non-null    float64
#  1   Gender                    235 non-null    object
#  2   Date_of_Birth             235 non-null    object
#  3   Department                235 non-null    object
#  4   Level                     235 non-null    object
#  5   Group                     235 non-null    object
#  6   Continuous_Evaluation_01  235 non-null    int64
#  7   Test_01                   235 non-null    float64
#  8   Exam_01                   235 non-null    float64
#  9   FIRST_TRIO                235 non-null    float64
#  10  Continuous_Evaluation_02  235 non-null    int64
#  11  Test_02                   235 non-null    float64
#  12  Exam_02                   235 non-null    float64
# ...

# %% [markdown]
# #### Drop some columns
# - 'Identification_Number' and 'Date_of_Birth' have no effect on data analysis

# %%
df.drop(['Identification_Number', 'Date_of_Birth'], axis=1, inplace=True)
df
# Out:
#     Gender                                     Department             Level  \
# 0        F                          Experimental-Sciences  Second_secondary
# 1        F                          Experimental-Sciences  Second_secondary
# 2        F                          Experimental-Sciences  Second_secondary
# 3        F                          Experimental-Sciences  Second_secondary
# 4        F                          Experimental-Sciences  Second_secondary
# ..     ...                                            ...               ...
# 230      M  Mathematics_technician_electrical_engineering   Third_secondary
# 231      M  Mathematics_technician_electrical_engineering   Third_secondary
# 232      M  Mathematics_technician_electrical_engineering   Third_secondary
# 233      M  Mathematics_technician_electrical_engineering   Third_secondary
# 234      M  Mathematics_technician_electrical_engineering   Third_secondary
#
# ...

# %% [markdown]
# #### Check columns now

# %%
NumCols=df.columns
NumCols
# Out:
# Index(['Gender', 'Department', 'Level', 'Group', 'Continuous_Evaluation_01',
#        'Test_01', 'Exam_01', 'FIRST_TRIO', 'Continuous_Evaluation_02',
#        'Test_02', 'Exam_02', 'SECOND_TRIO', 'Continuous_Evaluation_03',
#        'Test_03', 'Exam_03', 'THIRD_TRIO', 'Annual_ Rate', 'Result'],
#       dtype='object')

# %% [markdown]
# <a id='1.2'></a>
# ## View some statistical information

# %%
df.describe()
# Out:
#        Continuous_Evaluation_01     Test_01     Exam_01  FIRST_TRIO  \
# count                235.000000  235.000000  235.000000  235.000000
# mean                  13.272340   10.527660   21.773191   11.390170
# std                    2.176575    4.478615    9.347723    3.610053
# min                    9.000000    0.000000    0.500000    3.000000
# 25%                   12.000000    7.000000   15.500000    8.940000
# 50%                   14.000000   10.750000   22.500000   11.560000
# 75%                   15.000000   13.750000   28.500000   13.955000
# max                   16.000000   20.000000   40.000000   18.880000
#
#        Continuous_Evaluation_02     Test_02     Exam_02  SECOND_TRIO  \
# count                235.000000  235.000000  235.000000   235.000000
# mean                  11.953191   10.740426   17.506383    10.046936
# std                    3.300146    5.466943   10.393588     4.276354
# min                    0.000000    0.000000    0.000000     0.000000
# ...

# %% [markdown]
# #### Compare between FIRST, SECOND, THIRD TRIO

# %%
compare_df = df[['FIRST_TRIO','SECOND_TRIO', 'THIRD_TRIO']]
compare_df
# Out:
#      FIRST_TRIO  SECOND_TRIO  THIRD_TRIO
# 0         17.00        16.69       17.62
# 1         15.56        12.33       15.58
# 2         12.91         8.62       12.25
# 3         15.69        15.38       17.12
# 4         16.88        16.88       17.38
# ..          ...          ...         ...
# 230        8.44         6.38        8.38
# 231       10.94        14.83       10.31
# 232        6.88         4.62        2.25
# 233       14.50        15.88       14.06
# 234        6.12         7.38        4.62
#
# [235 rows x 3 columns]

# %% [markdown]
# ##### TRIO'S Average

# %%
me= compare_df.mean()
print(" TRIO'S Average")
me
# Out:
#  TRIO'S Average
# FIRST_TRIO     11.390170
# SECOND_TRIO    10.046936
# THIRD_TRIO     11.545021
# dtype: float64

# %% [markdown]
# #### The Highest & lowest Annual Rate

# %%
highest = df.sort_values('Annual_ Rate', ascending=False).head(10)
highest
# Out:
#     Gender             Department             Level Group  \
# 64       F  Experimental-Sciences  Second_secondary   2_2
# 31       F  Experimental-Sciences  Second_secondary   2_1
# 76       F  Experimental-Sciences  Second_secondary   2_2
# 79       F  Experimental-Sciences  Second_secondary   2_2
# 12       M  Experimental-Sciences  Second_secondary   2_1
# 171      F  Experimental-Sciences   Third_secondary   3_3
# 27       F  Experimental-Sciences  Second_secondary   2_1
# 178      F  Experimental-Sciences   Third_secondary   3_3
# 0        F  Experimental-Sciences  Second_secondary   2_1
# 4        F  Experimental-Sciences  Second_secondary   2_1
#
#      Continuous_Evaluation_01  Test_01  Exam_01  FIRST_TRIO  \
# 64                         16    20.00     34.5       17.62
# 31                         16    17.50     37.0       17.62
# 76                         16    18.25     38.5       18.19
# 79                         16    19.75     36.0       17.94
# ...

# %%
lowest = df.sort_values('Annual_ Rate', ascending=True).head(10)
lowest
# Out:
#     Gender                                     Department            Level  \
# 123      F                          literature_philosophy  Third_secondary
# 213      F     Mathematics_technician_Methods_engineering  Third_secondary
# 98       M                          literature_philosophy  Third_secondary
# 215      F     Mathematics_technician_Methods_engineering  Third_secondary
# 92       M                          literature_philosophy  Third_secondary
# 90       F                          literature_philosophy  Third_secondary
# 105      F                          literature_philosophy  Third_secondary
# 229      M  Mathematics_technician_electrical_engineering  Third_secondary
# 93       F                          literature_philosophy  Third_secondary
# 150      M                          Experimental-Sciences  Third_secondary
#
#     Group  Continuous_Evaluation_01  Test_01  Exam_01  FIRST_TRIO  \
# 123   3_1                        10     0.50      5.0        3.88
# ...

# %% [markdown]
# <a id='2'></a>
# # 2 | Make Charts

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: #66CDAA; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;">  📊 Make Charts</p>

# %% [markdown]
# <a id='2.1'></a>
# ## Pie Charts

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: dimgray; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;">  Pie Charts </p>

# %% [markdown]
# ### Gender

# %%
# Total count
total_cnt = df.Gender.count()
total_cnt
# Out:
# 235

# %%
# Count
female_cnt = df.Gender[df.Gender=='F'].count()
male_cnt = df.Gender[df.Gender=='M'].count()
print('Female count is {} and Male count is {} in Total'.format(int(female_cnt), int(male_cnt)))
# Out:
# Female count is 154 and Male count is 81 in Total

# %%
# Rate
fem_rate = female_cnt / total_cnt
print("The overall Female rate is {:.2f} %.".format(fem_rate*100))
mal_rate = male_cnt / total_cnt
print("The overall Male rate is {:.2f} %.".format(mal_rate*100))
# Out:
# The overall Female rate is 65.53 %.
# The overall Male rate is 34.47 %.

# %%
# Pie Chart
labels = ['Female', 'Male']
gender_sizes = [154, 81]
explode = (0.01, 0) 

#add colors
colors = ['#ff9999','#66b3ff']

fig1, ax1 = plt.subplots()
ax1.pie(gender_sizes, explode=explode, colors = colors, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  
ax1.set_title("Female & Male Rate\n")

plt.show()

# %% [markdown]
# ### Departments

# %%
# Count
lit_cnt = df.Department[df.Department=='literature_philosophy'].count()
exp_cnt = df.Department[df.Department=='Experimental-Sciences'].count()
meth_cnt = df.Department[df.Department=='Mathematics_technician_Methods_engineering'].count()
elec_cnt = df.Department[df.Department=='Mathematics_technician_electrical_engineering'].count()

print('literaturePhilosophy count is {} and Experimental Sciences count is {} and Methods engineering count is {} and electrical engineering count is {} in Total'.format(int(lit_cnt), int(exp_cnt),int(meth_cnt), int(elec_cnt)))
# Out:
# literaturePhilosophy count is 44 and Experimental Sciences count is 168 and Methods engineering count is 16 and electrical engineering count is 7 in Total

# %%
# Pie Charts
labels = ['literature-philosophy', 'Experimental-Sciences', 'Methods-engineering','Electrical-engineering']
depar_sizes = [44, 168, 16, 7]
explode = (0, 0, 0.1 ,0.3) 
colors = ['#ffcc99', '#c2c2f0','khaki','pink']

fig1, ax1 = plt.subplots()
ax1.pie(depar_sizes, explode=explode, colors = colors, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  
ax1.set_title("Departments \n")

plt.show()

# %% [markdown]
# ### Level

# %%
# Count
second_cnt = df.Level[df.Level == 'Second_secondary'].count()
third_cnt = df.Level[df.Level == 'Third_secondary'].count()
print('Second secondary count is {} and Third secondary count is {} in Total'.format(int(second_cnt), int(third_cnt)))
# Out:
# Second secondary count is 81 and Third secondary count is 154 in Total

# %%
# Pie Chart
labels = ['Second', 'Third']
edy_sizes = [81, 154]
explode = (0.1, 0) 
colors = ["#B9DDF1","#2E5B88"]

fig1, ax1 = plt.subplots()
ax1.pie(edy_sizes, explode=explode, colors = colors, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  
ax1.set_title("Level\n")

plt.show()

# %% [markdown]
# ### Result

# %%
# Count
success_cnt = df.Result[df.Result == "PASS"].count()
fail_cnt = df.Result[df.Result == "FAILD"].count()
print('Successful students count is {} and Failing students count is {} in Total'.format(int(success_cnt), int(fail_cnt)))
# Out:
# Successful students count is 137 and Failing students count is 98 in Total

# %%
# Pie Chart
labels = ['PASS', 'FAILD']
totavg_sizes = [137, 98]
explode = (0, 0) 
colors = ['#99ff99','#ff9999']
fig1, ax1 = plt.subplots()
ax1.pie(totavg_sizes, explode=explode, colors = colors, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  
ax1.set_title("Result\n")

plt.show()

# %% [markdown]
# <a id='2.2'></a>
# ## Distributions

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: dimgray; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> Distributions </p>

# %% [markdown]
# ### FIRST, SECOND, THIRD TRIO

# %%
# First
plt.title("Distribution of FIRST TRIO")
sns.histplot(df.FIRST_TRIO, kde=True, color='#66CDAA');

# %%
# Second
plt.title("Distribution of SECOND TRIO")
sns.histplot(df.SECOND_TRIO, kde=True, color='#66CDAA');

# %%
# Third
plt.title("Distribution of THIRD TRIO")
sns.histplot(df.THIRD_TRIO, kde=True, color='#66CDAA');

# %%
# Annual Rate
plt.figure(figsize=(12,6))
plt.title("Distribution of Annual Rate")
plt.xlabel('Annual Rate')
plt.ylabel('Values')
plt.hist(df['Annual_ Rate'], bins=np.arange(1, 25, 5), color='#458B74');

# %% [markdown]
# <a id='2.3'></a>
# ## Bar Charts

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: dimgray; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> Bar Charts </p>

# %% [markdown]
# #### Averages by trimesters

# %%
# Count
me= compare_df.mean()
print(" TRIO'S Average")
me
# Out:
#  TRIO'S Average
# FIRST_TRIO     11.390170
# SECOND_TRIO    10.046936
# THIRD_TRIO     11.545021
# dtype: float64

# %%
# Bar
plt.figure(figsize=(12,6))
plt.title('Averages by TRIO')
me.plot(kind='bar', color='g');

# %% [markdown]
# ###  Averages by Gender

# %%
# Avrg
gender_avrg = df.groupby('Gender')[['Annual_ Rate']].mean()
gender_avrg
# Out:
#         Annual_ Rate
# Gender
# F          11.259416
# M          10.489630

# %%
# Bar
labels = ['Annual_ Rate']
fem = [11.26]
mal = [10.49]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, fem, width, label='Female', color='#ff9999')
rects2 = ax.bar(x + width/2, mal, width, label='Male', color='#66b3ff')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
ax.set_title('Averages by Gender\n')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='center right', bbox_to_anchor=(1, 1.03))


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# ### Averages by Department

# %%
# Avrg
Department_avrg = df.groupby('Department')[['Annual_ Rate']].mean()
Department_avrg
# Out:
#                                                Annual_ Rate
# Department
# Experimental-Sciences                             12.060060
# Mathematics_technician_Methods_engineering         8.046250
# Mathematics_technician_electrical_engineering      8.662857
# literature_philosophy                              8.366818

# %%
# Bar
labels = ['Annual_ Rate']
es = [12.06]
lp =[8.37]
met =[8.05]
elec = [8.66]

x = np.arange(len(labels))  # the label locations
width = 0.38  # the width of the bars  

fig, ax = plt.subplots()
rects1 = ax.bar( x - width/2, es, width, label='Experimental-Sciences', color='#c2c2f0')
rects2 = ax.bar( x + 2*width/2, lp, width, label='literature-philosophy', color='#ffcc99')
rects3 = ax.bar( x - 2*width, met, width, label='Methods-engineering', color='#CDC8B1')
rects4 = ax.bar(x + 2.5*width, elec, width, label='electrical-engineering', color='#8B8878')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
ax.set_title('Averages by Department\n')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='center right', bbox_to_anchor=(1.4, 1.05))


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Averages by Level

# %%
# Avrg
Level_avrg = df.groupby('Level')[['Annual_ Rate']].mean()
Level_avrg
# Out:
#                   Annual_ Rate
# Level
# Second_secondary     13.445556
# Third_secondary       9.704675

# %%
# Bar
labels = ['Level']
sec = [13.44]
thi =[9.71]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars  

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, sec, width, label='Second', color='#B9DDF1')
rects2 = ax.bar(x + width/2, thi, width, label='Third', color='#2E5B88')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
ax.set_title('Averages by  Level\n')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend(loc='center right', bbox_to_anchor=(1, 1.05))


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Averages by Group

# %%
# Average
Group_avrg = df.groupby('Group')[['Annual_ Rate']].mean()
Group_avrg
# Out:
#        Annual_ Rate
# Group
# 2_1       13.905610
# 2_2       12.974000
# 3_1        8.366818
# 3_2       10.530465
# 3_3       11.004318
# 3_4        8.046250
# 3_5        8.662857

# %%
# Bar
plt.figure(figsize=(12,6))
plt.title('Averages by Group')
Group_avrg['Annual_ Rate'].plot(kind='bar', color='tan');

# %% [markdown]
# <a id='2.4'></a>
# ## Scatter plot

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: dimgray; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> Scatter plot </p>

# %% [markdown]
# ### Gender

# %%
sns.scatterplot(data=df, x="FIRST_TRIO", y="Annual_ Rate", hue="Gender",s=40,
               palette=['#FF1493','#00BFFF'], legend='full')
plt.title('Gender');

# %% [markdown]
# ### Level

# %%
sns.scatterplot(data=df, x="FIRST_TRIO", y="Annual_ Rate", hue="Level", s=40,
               palette=['yellow', 'black'], legend='full')
plt.title('Level');

# %% [markdown]
# ### Result

# %%
sns.scatterplot(data=df, x="FIRST_TRIO", y="Annual_ Rate", hue="Result", s=40,
               palette=['g', 'red'], legend='full')
plt.title('Result');

# %%
sns.scatterplot(data=df, x="SECOND_TRIO", y="Annual_ Rate", hue="Result", s=40,
               palette=['g', 'red'], legend='full')
plt.title('Result');

# %%
sns.scatterplot(data=df, x="THIRD_TRIO", y="Annual_ Rate", hue="Result", s=40,
               palette=['g', 'red'], legend='full')
plt.title('Result');

# %%
sns.scatterplot(data=df, x="SECOND_TRIO", y="THIRD_TRIO", hue="Result", s=40,
               palette=['g', 'red'], legend='full')
plt.title('Result');

# %%
sns.scatterplot(data=df, x="FIRST_TRIO", y="SECOND_TRIO", hue="Result", s=40,
               palette=['g', 'red'], legend='full')
plt.title('Result');

# %%
sns.scatterplot(data=df, x="FIRST_TRIO", y="THIRD_TRIO", hue="Result", s=40,
               palette=['g', 'red'], legend='full')
plt.title('Result');

# %% [markdown]
# <a id='3'></a>
# # 3 | Extract Relations

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: #66CDAA; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> 📈 Extract Relations</p>

# %% [markdown]
# <a id='3.1'></a>
# ## FIRST TRIO

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: lightcoral; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> FIRST TRIO </p>

# %% [markdown]
# FIRST TRIO file

# %%
# FIRST TRIO file
first_df = df.groupby('Department')[['Continuous_Evaluation_01','Test_01','Exam_01','FIRST_TRIO']].mean()
first_df
# Out:
#                                                Continuous_Evaluation_01  \
# Department
# Experimental-Sciences                                         13.767857
# Mathematics_technician_Methods_engineering                    11.000000
# Mathematics_technician_electrical_engineering                 11.142857
# literature_philosophy                                         12.545455
#
#                                                  Test_01    Exam_01  \
# Department
# Experimental-Sciences                          11.886905  24.450595
# Mathematics_technician_Methods_engineering      6.640625  16.750000
# Mathematics_technician_electrical_engineering   7.071429  19.857143
# literature_philosophy                           7.301136  13.681818
#
#                                                FIRST_TRIO
# Department
# Experimental-Sciences                           12.522381
# Mathematics_technician_Methods_engineering       8.596875
# ...

# %%
# FIRST TRIO Average
plt.title('FIRST TRIO Average')
first_df.FIRST_TRIO.plot(kind='barh', color='gray');

# %%
# Heatmap
sns.heatmap(first_df, cmap='coolwarm')
plt.show()

# %%
#Setting the value for X and Y
X = df[['Test_01', 'Exam_01']]
y = df['FIRST_TRIO']

# %%
# Checking for outliers
fig, axs = plt.subplots(1, figsize = (5,5))
print('Continuous Evaluation 01 Outliers')
plt1 = sns.boxplot(df['Continuous_Evaluation_01'])
plt.tight_layout()
# Out:
# Continuous Evaluation 01 Outliers

# %%
# Checking for outliers
fig, axs = plt.subplots(1, figsize = (5,5))
print('Test 01 Outliers')
plt1 = sns.boxplot(df['Test_01'])
plt.tight_layout()
# Out:
# Test 01 Outliers

# %%
# Checking for outliers
fig, axs = plt.subplots(1, figsize = (5,5))
print('Exam 01 Outliers')
plt1 = sns.boxplot(df['Exam_01'])
plt.tight_layout()
# Out:
# Exam 01 Outliers

# %%
# Distribution of the target variable
sns.distplot(df['FIRST_TRIO']);
# It is normally distributed ??

# %%
sns.pairplot(df, x_vars=['Continuous_Evaluation_01','Test_01', 'Exam_01'],
             y_vars='FIRST_TRIO', height=4, aspect=1, kind='scatter')
plt.show()

# %%
print("correlation between 'Continuous_Evaluation_01' and 'FIRST_TRIO'")
print(df['Continuous_Evaluation_01'].corr(df['FIRST_TRIO']))
print("-------------------")

print("correlation between 'Test_01' and 'FIRST_TRIO'")
print(df['Test_01'].corr(df['FIRST_TRIO']))
print("-------------------")
 
print("correlation between 'Exam_01' and 'FIRST_TRIO'")
print(df['Exam_01'].corr(df['FIRST_TRIO']))
print("-------------------")
# Out:
# correlation between 'Continuous_Evaluation_01' and 'FIRST_TRIO'
# 0.8611124780353369
# -------------------
# correlation between 'Test_01' and 'FIRST_TRIO'
# 0.8225436727705231
# -------------------
# correlation between 'Exam_01' and 'FIRST_TRIO'
# 0.9511547982530072
# -------------------

# %%
fig, axs = plt.subplots(ncols=3, figsize=(15,7))
sns.regplot(x='Continuous_Evaluation_01', y='FIRST_TRIO', data=df, ax=axs[0])
sns.regplot(x='Test_01', y='FIRST_TRIO', data=df, ax=axs[1])
sns.regplot(x='Exam_01', y='FIRST_TRIO', data=df, ax=axs[2]);

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
y_train.shape
# Out:
# (164,)

# %%
y_test.shape
# Out:
# (71,)

# %%
reg_model = linear_model.LinearRegression()

# %%
#Fitting the Multiple Linear Regression model
reg_model = LinearRegression().fit(X_train, y_train)

# %%
#Printing the model coefficients
print('Intercept: ',reg_model.intercept_)
# pair the feature names with the coefficients
list(zip(X, reg_model.coef_))
# Out:
# Intercept:  2.173780579065994
# [('Test_01', 0.29674370700772046), ('Exam_01', 0.28025933703620004)]

# %%
#Predicting the Test and Train set result 
y_pred= reg_model.predict(X_test)  
x_pred= reg_model.predict(X_train)

# %%
#Actual value and the predicted value
reg_model_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred})
reg_model_diff
# Out:
#      Actual value  Predicted value
# 165         18.88        19.170656
# 179         10.62        10.350742
# 133         16.19        16.038357
# 148         13.31        13.548991
# 59          16.81        16.788458
# ..            ...              ...
# 75          11.56        11.471773
# 182         14.56        14.505173
# 214          8.25         8.677441
# 156          9.75         9.922111
# 126         11.44        11.760287
#
# [71 rows x 2 columns]

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print('Mean Absolute Error:', mae)
print('Mean Square Error:', mse)
print('Root Mean Square Error:', r2)
# Out:
# Mean Absolute Error: 0.22725763776927996
# Mean Square Error: 0.09283793928770372
# Root Mean Square Error: 0.30469318877799634

# %% [markdown]
# ### Predicted FIRST TRIO

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color:coral; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> Predicted FIRST TRIO = $2.17$ + $0.3$ * (Test_01) + $0.28$ * (Exam_01) </p>
#
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color:coral; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> The Continuous Evaluation score played a role in increasing the student’s original average by about 2.17 in the FIRST TRIO </p>

# %% [markdown]
# <a id='3.2'></a>
# ## SECOND TRIO

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: lightcoral; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> SECOND TRIO </p>

# %% [markdown]
# SECOND TRIO file

# %%
# SECOND TRIO file
second_df = df.groupby('Department')[['Continuous_Evaluation_02', 'Test_02','Exam_02','SECOND_TRIO']].mean()
second_df
# Out:
#                                                Continuous_Evaluation_02  \
# Department
# Experimental-Sciences                                         12.660714
# Mathematics_technician_Methods_engineering                     9.375000
# Mathematics_technician_electrical_engineering                  9.428571
# literature_philosophy                                         10.590909
#
#                                                  Test_02    Exam_02  \
# Department
# Experimental-Sciences                          11.025298  19.491071
# Mathematics_technician_Methods_engineering      9.906250  12.031250
# Mathematics_technician_electrical_engineering  11.428571  13.071429
# literature_philosophy                           9.846591  12.625000
#
#                                                SECOND_TRIO
# Department
# Experimental-Sciences                            10.791369
# Mathematics_technician_Methods_engineering        7.825625
# ...

# %%
# SECOND  TRIO Average
plt.title('SECOND  TRIO Average')
second_df.SECOND_TRIO.plot(kind='barh', color='gray');

# %%
# Heatmap
sns.heatmap(second_df, cmap='coolwarm')
plt.show()

# %%
#Setting the value for X and Y
X = df[['Test_02', 'Exam_02']]
y = df['SECOND_TRIO']

# %%
# Checking for outliers
fig, axs = plt.subplots(1, figsize = (5,5))
print('Continuous Evaluation 02 Outliers')
plt1 = sns.boxplot(df['Continuous_Evaluation_02'])
plt.tight_layout()
# Out:
# Continuous Evaluation 02 Outliers

# %%
# Checking for outliers
fig, axs = plt.subplots(1, figsize = (5,5))
print('Test 02 Outliers')
plt1 = sns.boxplot(df['Test_02'])
plt.tight_layout()
# Out:
# Test 02 Outliers

# %%
# Checking for outliers
fig, axs = plt.subplots(1, figsize = (5,5))
print('Exam 02 Outliers')
plt1 = sns.boxplot(df['Exam_02'])
plt.tight_layout()
# Out:
# Exam 02 Outliers

# %%
# Distribution of the target variable
sns.distplot(df['SECOND_TRIO']);
# It is normally distributed ??

# %%
sns.pairplot(df, x_vars=['Continuous_Evaluation_02','Test_02', 'Exam_02'],
             y_vars='SECOND_TRIO', height=4, aspect=1, kind='scatter')
plt.show()

# %%
print("correlation between 'Continuous_Evaluation_02' and 'SECOND_TRIO'")
print(df['Continuous_Evaluation_02'].corr(df['SECOND_TRIO']))
print("-------------------")

print("correlation between 'Test_02' and 'SECOND_TRIO'")
print(df['Test_02'].corr(df['SECOND_TRIO']))
print("-------------------")
 
print("correlation between 'Exam_02' and 'SECOND_TRIO'")
print(df['Exam_02'].corr(df['SECOND_TRIO']))
print("-------------------")
# Out:
# correlation between 'Continuous_Evaluation_02' and 'SECOND_TRIO'
# 0.9145364519509358
# -------------------
# correlation between 'Test_02' and 'SECOND_TRIO'
# 0.7911325622156418
# -------------------
# correlation between 'Exam_02' and 'SECOND_TRIO'
# 0.9386146483564553
# -------------------

# %%
fig, axs = plt.subplots(ncols=3, figsize=(15,7))
sns.regplot(x='Continuous_Evaluation_02', y='SECOND_TRIO', data=df, ax=axs[0])
sns.regplot(x='Test_02', y='SECOND_TRIO', data=df, ax=axs[1])
sns.regplot(x='Exam_02', y='SECOND_TRIO', data=df, ax=axs[2]);

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
reg_model = linear_model.LinearRegression()
#Fitting the Multiple Linear Regression model
reg_model = LinearRegression().fit(X_train, y_train)

# %%
#Printing the model coefficients
print('Intercept: ',reg_model.intercept_)
# pair the feature names with the coefficients
list(zip(X, reg_model.coef_))
# Out:
# Intercept:  1.539884795638132
# [('Test_02', 0.3061850302538295), ('Exam_02', 0.29836627821439177)]

# %%
#Predicting the Test and Train set result 
y_pred= reg_model.predict(X_test)  
x_pred= reg_model.predict(X_train)

# %%
#Actual value and the predicted value
reg_model_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred})
reg_model_diff
# Out:
#      Actual value  Predicted value
# 165         10.83        10.789239
# 179          7.62         7.750219
# 133         14.50        14.184640
# 148         14.67        14.345552
# 59          17.38        17.639309
# ..            ...              ...
# 75          10.25        10.339422
# 182         11.50        11.499344
# 214         12.62        13.132540
# 156         11.83        11.770345
# 126         12.00        11.919528
#
# [71 rows x 2 columns]

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print('Mean Absolute Error:', mae)
print('Mean Square Error:', mse)
print('Root Mean Square Error:', r2)
# Out:
# Mean Absolute Error: 0.28918321266337293
# Mean Square Error: 0.16004041106376096
# Root Mean Square Error: 0.4000505106405452

# %% [markdown]
# ### Predicted SECOND TRIO

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: coral; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> Predicted SECOND TRIO = $1.54$ + $0.3$ * (Test_02) + $0.3$ * (Exam_02) </p>
#
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color:coral; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> The Continuous Evaluation score played a role in increasing the student’s original average by about 1.54 in the SECOND TRIO </p>

# %% [markdown]
# <a id='3.3'></a>
# ## THIRD TRIO

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: lightcoral; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> THIRD TRIO </p>

# %% [markdown]
# THIRD TRIO file

# %%
# THIRD TRIO file
third_df = df.groupby('Department')[['Continuous_Evaluation_03', 'Test_03','Exam_03', 'THIRD_TRIO']].mean()
third_df
# Out:
#                                                Continuous_Evaluation_03  \
# Department
# Experimental-Sciences                                         13.708333
# Mathematics_technician_Methods_engineering                     9.875000
# Mathematics_technician_electrical_engineering                  9.428571
# literature_philosophy                                         10.840909
#
#                                                  Test_03    Exam_03  \
# Department
# Experimental-Sciences                          14.406250  23.348214
# Mathematics_technician_Methods_engineering      7.906250  13.093750
# Mathematics_technician_electrical_engineering   7.928571  14.571429
# literature_philosophy                          13.022727  10.000000
#
#                                                THIRD_TRIO
# Department
# Experimental-Sciences                           12.866071
# Mathematics_technician_Methods_engineering       7.715625
# ...

# %%
# THIRD TRIO Average
plt.title('THIRD TRIO Average')
third_df.THIRD_TRIO.plot(kind='barh', color='gray');

# %%
# Heatmap
sns.heatmap(third_df, cmap='coolwarm')
plt.show()

# %%
#Setting the value for X and Y
X = df[['Test_03', 'Exam_03']]
y = df['THIRD_TRIO']

# %%
# Checking for outliers
fig, axs = plt.subplots(1, figsize = (5,5))
print('Continuous Evaluation 03 Outliers')
plt1 = sns.boxplot(df['Continuous_Evaluation_03'])
plt.tight_layout()
# Out:
# Continuous Evaluation 03 Outliers

# %%
# Checking for outliers
fig, axs = plt.subplots(1, figsize = (5,5))
print('Test 03 Outliers')
plt1 = sns.boxplot(df['Test_03'])
plt.tight_layout()
# Out:
# Test 03 Outliers

# %%
# Checking for outliers
fig, axs = plt.subplots(1, figsize = (5,5))
print('Exam 03 Outliers')
plt1 = sns.boxplot(df['Exam_03'])
plt.tight_layout()
# Out:
# Exam 03 Outliers

# %%
# Distribution of the target variable
sns.distplot(df['THIRD_TRIO']);
# It is normally distributed ??

# %%
sns.pairplot(df, x_vars=['Continuous_Evaluation_03','Test_03', 'Exam_03'],
             y_vars='THIRD_TRIO', height=4, aspect=1, kind='scatter')
plt.show()

# %%
print("correlation between 'Continuous_Evaluation_03' and 'THIRD_TRIO'")
print(df['Continuous_Evaluation_03'].corr(df['THIRD_TRIO']))
print("-------------------")

print("correlation between 'Test_03' and 'THIRD_TRIO'")
print(df['Test_03'].corr(df['THIRD_TRIO']))
print("-------------------")
 
print("correlation between 'Exam_03' and 'THIRD_TRIO'")
print(df['Exam_03'].corr(df['THIRD_TRIO']))
print("-------------------")
# Out:
# correlation between 'Continuous_Evaluation_03' and 'THIRD_TRIO'
# 0.7900751028936643
# -------------------
# correlation between 'Test_03' and 'THIRD_TRIO'
# 0.8125135433497102
# -------------------
# correlation between 'Exam_03' and 'THIRD_TRIO'
# 0.9330054431203585
# -------------------

# %%
fig, axs = plt.subplots(ncols=3, figsize=(15,7))
sns.regplot(x='Continuous_Evaluation_03', y='THIRD_TRIO', data=df, ax=axs[0])
sns.regplot(x='Test_03', y='THIRD_TRIO', data=df, ax=axs[1])
sns.regplot(x='Exam_03', y='THIRD_TRIO', data=df, ax=axs[2]);

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
reg_model = linear_model.LinearRegression()
#Fitting the Multiple Linear Regression model
reg_model = LinearRegression().fit(X_train, y_train)

# %%
#Printing the model coefficients
print('Intercept: ',reg_model.intercept_)
# pair the feature names with the coefficients
list(zip(X, reg_model.coef_))
# Out:
# Intercept:  1.963810040122281
# [('Test_03', 0.27787709311874564), ('Exam_03', 0.2930039211282362)]

# %%
#Predicting the Test and Train set result 
y_pred= reg_model.predict(X_test)  
x_pred= reg_model.predict(X_train)

# %%
#Actual value and the predicted value
reg_model_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred})
reg_model_diff
# Out:
#      Actual value  Predicted value
# 165         12.46        12.762372
# 179         11.12        11.769909
# 133         16.94        16.865825
# 148         15.48        15.138055
# 59          15.50        15.139454
# ..            ...              ...
# 75          15.38        15.308646
# 182         14.88        14.992952
# 214          9.00         8.874890
# 156          8.58         8.011005
# 126         14.88        15.139454
#
# [71 rows x 2 columns]

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print('Mean Absolute Error:', mae)
print('Mean Square Error:', mse)
print('Root Mean Square Error:', r2)
# Out:
# Mean Absolute Error: 0.4677565321508253
# Mean Square Error: 0.404643078914958
# Root Mean Square Error: 0.6361156175688174

# %% [markdown]
# ### Predicted THIRD TRIO

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: coral; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> Preddicted THIRD TRIO = $1.96$ + $0.28$ * (Test_03) + $0.29$ * (Exam_03) </p>
#
# 1. ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color:coral; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> The Continuous Evaluation score played a role in increasing the student’s original average by about 1.96 in the THIRD TRIO </p>

# %% [markdown]
# # <a id='3.4'></a>
# ##  Extraction

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed coral; padding: 20px; background-color: white; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: coral; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;">Continuous Evaluation marks played a significant role in increasing the student's original averages by about 1.5 to 2 during the first, second, and third trimesters.</p>

# %% [markdown]
# <a id='4'></a>
# # 4 | Explore Pattern

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: #66CDAA; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;">🧩 Explore Pattern</p>

# %% [markdown]
# <a id='4.1'></a>
# ## Annual Rate

# %%
# The File
annual_df = df.groupby('Annual_ Rate')[['FIRST_TRIO','SECOND_TRIO', 'THIRD_TRIO']].mean()
annual_df
# Out:
#               FIRST_TRIO  SECOND_TRIO  THIRD_TRIO
# Annual_ Rate
# 2.27                3.88        1.500        1.44
# 2.62                4.62        2.000        1.25
# 2.85                3.00        3.620        1.94
# 2.88                8.62        0.000        0.00
# 2.94                3.75        2.250        2.81
# ...                  ...          ...         ...
# 17.71              16.78       18.345       18.00
# 17.94              17.94       17.380       18.50
# 18.02              18.19       17.380       18.50
# 18.10              17.62       17.810       18.88
# 18.29              17.62       18.500       18.75
#
# [215 rows x 3 columns]

# %%
j=0
k=0
fig,ax=plt.subplots(nrows=6,ncols=3,figsize=(18,30))
for i,fea in enumerate(NumCols[:-1]):
    if i==0:
        j=0
        k=0
    elif i%3==0:
        j=j+1
        k=0
    else:
        k=k+1

    ax[j,k].set_xlabel(fea)
    sns.scatterplot(data=df,x=df[fea],y=df['Annual_ Rate'],ax=ax[j,k])

# %%
j=0
k=0
fig,ax=plt.subplots(nrows=6,ncols=3,figsize=(18,30))
for i,fea in enumerate(NumCols):
    if i==0:
        j=0
        k=0
    elif i%3==0:
        j=j+1
        k=0
    else:
        k=k+1

    ax[j,k].set_xlabel(fea)
    sns.scatterplot(data=df,x=df[fea].value_counts(),y=df['Annual_ Rate'],ax=ax[j,k])

# %%
#Setting the value for X and Y
X = df[['Test_01', 'Exam_01', 'Test_02', 'Exam_02','Test_03', 'Exam_03']]
y = df['Annual_ Rate']

# %%
# Checking for outliers
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(df['FIRST_TRIO'], ax = axs[0])
plt2 = sns.boxplot(df['SECOND_TRIO'], ax = axs[1])
plt3 = sns.boxplot(df['THIRD_TRIO'], ax = axs[2])
plt.tight_layout()

# %%
# Distribution of the target variable
sns.distplot(df['Annual_ Rate']);
# It is normally distributed ??

# %%
sns.pairplot(df, x_vars=['FIRST_TRIO','SECOND_TRIO', 'THIRD_TRIO'],
             y_vars='Annual_ Rate', height=4, aspect=1, kind='scatter')
plt.show()

# %%
fig, axs = plt.subplots(ncols=3, figsize=(15,7))
sns.regplot(x='FIRST_TRIO', y='Annual_ Rate', data=df, ax=axs[0])
sns.regplot(x='SECOND_TRIO', y='Annual_ Rate', data=df, ax=axs[1])
sns.regplot(x='THIRD_TRIO', y='Annual_ Rate', data=df, ax=axs[2]);

# %%
print("correlation between ''FIRST_TRIO' and 'Annual_Rate'")
print(df['FIRST_TRIO'].corr(df['Annual_ Rate']))
print("-------------------")

print("correlation between 'SECOND_TRIO' and 'Annual_Rate'")
print(df['SECOND_TRIO'].corr(df['Annual_ Rate']))
print("-------------------")
 
print("correlation between 'THIRD_TRIO' and 'Annual_Rate'")
print(df['THIRD_TRIO'].corr(df['Annual_ Rate']))
print("-------------------")
# Out:
# correlation between ''FIRST_TRIO' and 'Annual_Rate'
# 0.8933242402983019
# -------------------
# correlation between 'SECOND_TRIO' and 'Annual_Rate'
# 0.8983628066982633
# -------------------
# correlation between 'THIRD_TRIO' and 'Annual_Rate'
# 0.9053967669977054
# -------------------

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
reg_model = linear_model.LinearRegression()

# %%
#Fitting the Multiple Linear Regression model
reg_model = LinearRegression().fit(X_train, y_train)

# %%
#Printing the model coefficients
print('Intercept: ',reg_model.intercept_)
# pair the feature names with the coefficients
list(zip(X, reg_model.coef_))
# Out:
# Intercept:  1.7155142549569184
# [('Test_01', 0.103238820616154),
#  ('Exam_01', 0.0955286629456445),
#  ('Test_02', 0.11121945691822392),
#  ('Exam_02', 0.10557801990382006),
#  ('Test_03', 0.09472250616599182),
#  ('Exam_03', 0.09025566681869575)]

# %%
#Predicting the Test and Train set result 
y_pred= reg_model.predict(X_test)  
x_pred= reg_model.predict(X_train)

# %%
#Actual value and the predicted value
reg_model_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred})
reg_model_diff
# Out:
#      Actual value  Predicted value
# 165         14.06        14.263159
# 179          9.79         9.961952
# 133         15.88        15.730847
# 148         14.49        14.397293
# 59          16.56        16.717185
# ..            ...              ...
# 75          12.40        12.337614
# 182         13.65        13.707279
# 214          9.96        10.282443
# 156         10.06         9.957945
# 126         12.77        12.944955
#
# [71 rows x 2 columns]

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print('Mean Absolute Error:', mae)
print('Mean Square Error:', mse)
print('Root Mean Square Error:', r2)
# Out:
# Mean Absolute Error: 0.2364830306490191
# Mean Square Error: 0.11446868343759656
# Root Mean Square Error: 0.3383322086908022

# %% [markdown]
# ### predicted Annual Rate Pattern

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed white; padding: 20px; background-color: #66CDAA; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color: white; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;">predicted Annual Rate = $1.715$ + $0.103$ * (Test_01) + $0.095$ * (Exam_01) + $0.111$ * (Test_02) + $0.105$ * (Exam_02)+ $0.095$ * (Test_03) + $0.090$ * (Exam_03)</p>

# %% [markdown]
# <a id='4.2'></a>
# ## Conclusion

# %% [markdown]
# ### <p style="width: 800px; border-radius: 12px; border: 3px dashed  #66CDAA; padding: 20px; background-color: white; text-align: center; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.3); color:  #66CDAA; text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.3); font-weight: bold; margin-bottom: 15px; font-size: 30px;"> (1) Second Trio marks played a significant role in the student's original final result. (2) Continuous Evaluation marks played a significant role in increasing the student's original final result by about 1.7 marks. (3) Accuracy in monitoring continuous evaluation marks plays a crucial role in determining a student's fate in History and Geography subject during the first, second, and third trimesters. (4) Subjecting the continuous evaluation mark to precise and specific criteria is necessary to ensure that the student's original results are not inflated.</p>
